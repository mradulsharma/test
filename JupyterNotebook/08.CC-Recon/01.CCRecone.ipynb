# %% [markdown]
# # CC Recon
# ![transform](Banner-01.png)
#
# This jupyter notebook will read Coles Credit Card, and extract data out of it :

# %%
# Import requried packages
from datetime import datetime, date
from pathlib import Path
import fitz  # PyMuPDF
import json
import re

# %%
# File path and static data 


# File path
file_path = "C:/<path>/Coles-Sep2025.pdf"


# Month mapping
month_order = {'Jan': 1, 'Feb': 2, 'Mar': 3, 'Apr': 4, 'May': 5, 'Jun': 6,
               'Jul': 7, 'Aug': 8, 'Sep': 9, 'Oct': 10, 'Nov': 11, 'Dec': 12}

# Regex patterns
date_pattern = re.compile(r"^\d{2}/\d{2}/\d{2}$")
amount_pattern = re.compile(r"^\$\d{1,3}(?:,\d{3})*\.\d{2}\s(?:Cr|Dr)$")
negative_amount_pattern = re.compile(r"^\$\d{1,3}(?:,\d{3})*\.\d{2}\sCr$")
payment_description = "BPAY Payments"

# Prepare vars
current_year = date.today().year
all_lines = []
tsv_with_dates = []
closing_balance = None
due_date = None

# %%
# Read PDF and collect ordered lines
pdf_path = Path(file_path)
doc = fitz.open(pdf_path)
for page in doc:
    blocks = page.get_text("blocks")
    blocks.sort(key=lambda b: (b[1], b[0]))
    for b in blocks:
        lines = b[4].splitlines()
        all_lines.extend([line.strip() for line in lines if line.strip()])
doc.close()

# DEBUG: print JSON version of all lines
#print(json.dumps(all_lines, indent=2, ensure_ascii=False))


# Single-pass loop to get closing balance, due date, and TSV transaction list
i = 0
while i < len(all_lines):
    current_line = all_lines[i].strip()
    next_line = all_lines[i + 1].strip() if i + 1 < len(all_lines) else ""
    next2_line = all_lines[i + 2].strip() if i + 2 < len(all_lines) else ""
    next3_line = all_lines[i + 3].strip() if i + 3 < len(all_lines) else ""

    # Check for closing balance
    if i >= 1:
        prev_line = all_lines[i - 1].strip()
        if prev_line == "= Closing Balance" and current_line.startswith("$") and not closing_balance:
            closing_balance = current_line.replace("$", "").replace(",", "").replace("Dr", "").replace("Cr", "").strip()

    # Check for due date
    if current_line == "Due by Payment Due Date" and next_line and not due_date:
        # Debug : Print next_line and due_date
        #print(f"\nnext_line & due_date => '{next_line}'\t'{due_date}'")
        try:
            parsed = datetime.strptime(next_line, "%d %b %y")
            due_date = parsed.strftime("%d-%b-%y")
        except ValueError:
            pass

    # Check for transaction
    if date_pattern.match(current_line):
        process_date_str = current_line # This is not being used, just storing in variable.
        txn_date_str = next_line
        desc = next2_line
        amount = next3_line
        ref = next3_line # There is no reference any more. This is not being used.

        # If it is payment received line, then skip loop by four.
        if desc == payment_description and negative_amount_pattern.match(amount):
            # DEBUG : Payment line found.
            #print(f"Payment line found '{desc}', '{amount}'")
            i += 4
            continue

        if date_pattern.match(process_date_str) and date_pattern.match(txn_date_str) and amount_pattern.match(amount):
            # DEBUG : Transaction line found.
            #print(f"Transaction line found '{amount}'")
            try:
                day, mon_num, date_yr = map(int, txn_date_str.split("/"))
                full_date = datetime(2000 + date_yr, mon_num, day)
                clean_amount = amount.replace("$", "").replace(",", "").replace("Dr", "").replace("Cr", "").strip()
                # DEBUG : clean_amount.
                #print(f"clean_amount '{clean_amount}'")
                text_date_for_txn_line = full_date.strftime("%b %d, %Y")
                tsv_with_dates.append((full_date, f"{text_date_for_txn_line}\t{desc}\t{clean_amount}"))
                i += 4
                continue
            except (KeyError, ValueError) as e:
                raise ValueError(f"Unable to construct tsv_with_dates '{day}', '{mon_num}', '{full_date}', '{desc}', '{amount}'  => {e}")

    i += 1

# Sort and convert to final TSV format
# DEBUG : PRint tsv_with_dates
#print("tsv_with_dates")
#print(tsv_with_dates)

tsv_with_dates.sort(key=lambda x: x[0])
tsv_lines = []
for _, line in tsv_with_dates:
    txn_date_str, desc, amount = line.split("\t")
    tsv_lines.append(f"{txn_date_str}  {desc}\t{amount}")

# %%
# Print summary and output
print(f"Lines {len(tsv_lines)}")
print(f"\n{closing_balance}\t{due_date}")
print(f"Closing balance {closing_balance}")
print(f"Payment Due Date: {due_date}" + "\n" * 4)
print("\n".join(tsv_lines))
